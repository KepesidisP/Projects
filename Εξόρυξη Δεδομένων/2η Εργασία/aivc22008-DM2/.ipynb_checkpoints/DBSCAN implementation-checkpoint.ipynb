# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.datasets import load_iris
from sklearn.cluster import DBSCAN

# %%
def showPlot(X,IDX):
    
    plt.figure(1)
    plt.scatter(X[:,0],X[:,1])
    plt.show()
    
    plt.figure(2)
    plt.scatter(X[:,0],X[:,1],c=IDX)
    plt.show()

# %% [markdown]
# # mydata Dataset

# %%
#mydata.mat

mat_file= scipy.io.loadmat('mydata.mat')
X=np.array(mat_file['X'])

epsilon=0.5
MinPts=15
dbscan= DBSCAN(epsilon, min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)

# %% [markdown]
# # Iris Dataset

# %%
#Iris data

meas=load_iris().data
X=meas[:,[0,1]]

epsilon=0.1
MinPts=5
dbscan= DBSCAN(epsilon,min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)

# %%
# 'Βήμα 5'
xV1=zscore(X[:,0])
xV2=zscore(X[:,1])
X= [xV1,xV2]
dbscan= DBSCAN(epsilon,min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8816\1583022287.py in <module>
#       6 IDX= dbscan.labels_
#       7
# ----> 8 showPlot(X,IDX)
#
# ~\AppData\Local\Temp\ipykernel_8816\1484539084.py in showPlot(X, IDX)
#       2
#       3     plt.figure(1)
# ----> 4     plt.scatter(X[:,0],X[:,1])
#       5     plt.show()
#       6
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# # xV Dataset

# %%
#xV dataset

mat_file= scipy.io.loadmat('xV.mat')
xV=np.array(mat_file['xV'])

X= xV[:,[0,1]]
epsilon=0.3
MinPts=50
dbscan= DBSCAN(epsilon,min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)

# %%
# 'Βήμα 3'
X= xV[:,[0,1]]
epsilon=0.6
MinPts=43
dbscan= DBSCAN(epsilon,min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)

# %%
# 'Βήμα 4'

X= xV[:,-2:]
epsilon=0.04
MinPts=4
dbscan= DBSCAN(epsilon,min_samples=MinPts).fit(X)
IDX= dbscan.labels_

showPlot(X,IDX)
